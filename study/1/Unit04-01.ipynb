# %%
import matplotlib.pyplot as plt
plt.title('BTC COIN')
plt.plot([10, 20, 30, 40], color='r', label='suicide rate')
plt.plot([40, 30, 20, 10], color='b', label='BTC coin')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('linestyle')
plt.plot([10, 20, 30, 40], color='r', linestyle='--', label='dashed')
plt.plot([40, 30, 20, 10], color='b', linestyle=':', label='dotted')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('marker')
plt.plot([10, 20, 30, 40], 'r.', label='circle')
plt.plot([40, 30, 20, 10], 'g^', label='triangle up')
plt.legend()
plt.show()

# %%
# 위 내용 합치기

import matplotlib.pyplot as plt
plt.title('marker')
plt.plot([10, 20, 30, 40], label='circle')
plt.plot([10, 20, 30, 40], 'r.')
plt.plot([40, 30, 20, 10], label='triangle up')
f = plt.plot([40, 30, 20, 10], 'g^')
plt.legend()
plt.show()
